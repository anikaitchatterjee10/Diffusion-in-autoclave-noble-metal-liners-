# %%
# !pip install jupyter_bokeh
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 45.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 111.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...

# %%
# !pip install ipympl

# %%
import numpy as np
from scipy.special import erf
import panel as pn
from bokeh.plotting import figure
from bokeh.models import HoverTool
from bokeh.palettes import Category10

pn.extension()

# 1. Diffusion Parameters
alloy_imp_dict = {
    "Ni": [(8.5e-11, 120.0), (2.38e-4, 203.0), (1.42e-4, 198.03)],
    "Cr": [(3.26e-4, 210.0), (2.58e-3, 225.93), (4.27e-4, 208.64)],
    "Fe": [(9.4e-11, 123.8), (4.66e-4, 209.47), (1.84e-4, 200.53)],
    "Mo": [(2.23e-6, 158.11), (2.58e-3, 225.93), (4.27e-4, 208.64)],
    "Co": [(3.00e-11, 124.3), (2.99e-4, 205.21), (1.57e-4, 199.03)],
    "Nb": [(1.52e-6, 154.4), (2.45e-2, 247.57), (1.69e-3, 221.88)],
    "Ti": [(1.33e-4, 198.0), (8.58e-4, 215.35), (2.45e-4, 203.31)],
    "Al": [(1.30e-5, 159.5)],
    "C":  [(1.08e-7, 128.98)],
    "Mn": [(1.8e-5, 179.6)],
    "Si": [(1.8e-5, 149.84), (5.55e-5, 189.01), (9.39e-5, 194.07)],
    "S":  [(1.65e-4, 167.36), (2.84e-6, 160.43), (4.12e-6, 164.01)],
    "P":  [(2.64e-7, 137.59), (2.37e-6, 158.69), (3.51e-6, 162.48)],
    "B":  [(2.28e-7, 136.19)],
    "Ta": [(2.87e-6, 160.52), (8.55e-2, 259.59), (5.74e-3, 233.62)],
    "Cu": [(1.23e-4, 193.0), (3.55e-5, 184.71), (6.07e-5, 189.88)],
    "W":  [(2.30e-6, 158.42), (1.42e-1, 264.45), (1.31e-2, 241.59)],
    "Zr": [(3.60e-6, 162.72), (3.90e-3, 229.91), (4.64e-4, 209.44)]
}

PERIODIC_GROUPS = {
    "All Elements": list(alloy_imp_dict.keys()),
    "Group 4 (Ti, Zr, Hf)": [el for el in ["Ti", "Zr", "Hf"] if el in alloy_imp_dict],
    "Group 5 (Nb, Ta)": [el for el in ["Nb", "Ta"] if el in alloy_imp_dict],
    "Group 6 (Cr, Mo, W)": [el for el in ["Cr", "Mo", "W"] if el in alloy_imp_dict],
    "Group 7 (Mn)": [el for el in ["Mn"] if el in alloy_imp_dict],
    "Group 8 (Fe)": [el for el in ["Fe"] if el in alloy_imp_dict],
    "Group 9 (Co)": [el for el in ["Co"] if el in alloy_imp_dict],
    "Group 10 (Ni)": [el for el in ["Ni"] if el in alloy_imp_dict],
    "Group 11 (Cu)": [el for el in ["Cu"] if el in alloy_imp_dict],
    "Group 13 (B, Al)": [el for el in ["B", "Al"] if el in alloy_imp_dict],
    "Group 14 (C, Si)": [el for el in ["C", "Si"] if el in alloy_imp_dict],
    "Group 15 (P)": [el for el in ["P"] if el in alloy_imp_dict],
    "Group 16 (S)": [el for el in ["S"] if el in alloy_imp_dict]
}

alloys = {
    "Inconel718": dict(dens=8.26, comp={"Ni": 52.5, "Fe":19, "Cr": 19, "Nb":5.125, "Mo":3.050, "Co":1, "Ti":0.9, "Al":0.5, "Mn":0.35, "Si":0.35, "Cu":0.3, "C":0.08, "Ta":0.05, "P":0.015, "S":0.015, "B":0.006, "W":0, "Zr":0}),
    "Inconel625": dict(dens=8.44, comp={"Ni": 58.6, "Fe":5, "Cr": 22, "Nb":1.75, "Mo":9, "Co":1, "Ti":0, "Al":0.4, "Mn":0.5, "Si":0, "Cu":0, "C":0, "Ta":1.75, "P":0, "S":0, "B":0, "W":0, "Zr":0}),
    "Rene41": dict(dens=8.249, comp={"Ni": 49.2585, "Fe":5, "Cr": 19, "Nb":0, "Mo":9.75, "Co":11, "Ti":3.15, "Al":1.6, "Mn":0.1, "Si":0.5, "Cu":0.5, "C":0.12, "Ta":0, "P":0, "S":0.015, "B":0.0065, "W":0, "Zr":0}),
    "Haynes282": dict(dens=8.28, comp={"Ni": 57, "Fe":1.5, "Cr": 20, "Nb":0, "Mo":8.5, "Co":10, "Ti":2.1, "Al":1.5, "Mn":0.3, "Si":0.15, "Cu":0, "C":0.06, "Ta":0, "P":0, "S":0, "B":0.005, "W":0, "Zr":0}),
    "U720Li": dict(dens=8.09, comp={"Ni": 57.061, "Fe":0, "Cr": 16.5, "Nb":0, "Mo":3, "Co":14.5, "Ti":5.075, "Al":2.55, "Mn":0, "Si":0, "Cu":0, "C":0.09, "Ta":0, "P":0, "S":0, "B":0.015, "W":1.25, "Zr":0.04}),
    "AD730": dict(dens=8.23, comp={"Ni": 58.1975, "Fe":4.3, "Cr": 16, "Nb":1.1, "Mo":3, "Co":9, "Ti":3.6, "Al":2.25, "Mn":0, "Si":0, "Cu":0, "C":0.01, "Ta":0, "P":0, "S":0, "B":0.0125, "W":2.5, "Zr":0.03}),
    "CoWAlloy1": dict(dens=8.83, comp={"Ni": 32, "Fe":0, "Cr": 12, "Nb":0, "Mo":0, "Co":42.3, "Ti":2.5, "Al":6, "Mn":0, "Si":0.4, "Cu":0, "C":0.08, "Ta":1.5, "P":0, "S":0, "B":0.08, "W":3, "Zr":0.01}),
    "CoWAlloy2": dict(dens=8.9, comp={"Ni": 32, "Fe":0, "Cr": 12, "Nb":0, "Mo":0, "Co":40.8, "Ti":0.3, "Al":9, "Mn":0, "Si":0.4, "Cu":0, "C":0.08, "Ta":0.2, "P":0, "S":0, "B":0.08, "W":5, "Zr":0.01}),
    "TZM": dict(dens=10.22, comp={"Ni": 0, "Fe":0, "Cr": 0.12, "Nb":0, "Mo":99.3714, "Co":0.408, "Ti":0.003, "Al":0.09, "Mn":0, "Si":0.004, "Cu":0, "C":0.0008, "Ta":0.0002, "P":0, "S":0, "B":0.0008, "W":0, "Zr":0})
}

atom_database = {
    "Ni": 58.69, "Fe": 55.85, "Cr": 52.00, "Nb": 92.91, "Mo": 95.95, "Co": 58.93,
    "Ti": 47.87, "Al": 26.98, "Mn": 54.94, "Si": 28.09, "Cu": 63.55, "C": 12.01,
    "Ta": 180.95, "P": 30.97, "S": 32.07, "B": 10.81, "W": 183.84, "Zr": 91.22
}

R = 8.31446e-3
ELEMENTS = list(alloy_imp_dict.keys())
COLORS = Category10[10] * 2
LINE_STYLES = ['solid', 'dashed', 'dotted']

# 2. UI Widgets (Updated slider range and name to reflect millimeters)
alloy_w = pn.widgets.Select(name="Alloy", options=list(alloys.keys()))
group_w = pn.widgets.Select(name="Periodic Group Filter", options=list(PERIODIC_GROUPS.keys()))
temp_w = pn.widgets.IntSlider(name="Temp °C", start=400, end=1000, value=650)
time_w = pn.widgets.IntInput(name="Time (days)", value=10)
thick_w = pn.widgets.FloatSlider(name="Thickness / Max Depth (mm)", start=0.1, end=3.0, value=1.0)
override_w = pn.widgets.Checkbox(name="Override Surface Conc.", value=False)
custom_c0_w = pn.widgets.FloatInput(name="Custom Conc. (cm⁻³)", value=1e20, disabled=True)

method_options = [f"Method {i+1}" for i in range(max(len(v) for v in alloy_imp_dict.values()))]
method_select = pn.widgets.MultiChoice(name="Select Diffusion Methods", options=method_options, value=method_options)

def update_custom_c0_state(target_widget, event):
    target_widget.disabled = not event.new
    if target_widget.disabled or target_widget.value is None or np.isnan(target_widget.value):
        target_widget.value = 1e20

override_w.link(custom_c0_w, callbacks={'value': update_custom_c0_state})

# 3. Reactive Plot Generator
def create_plot(alloy, group, temp, days, thick, override, custom_c0, selected_methods):
    t_sec_now = days * 86400
    T_k = temp + 273.15
    allowed = PERIODIC_GROUPS[group]
    comp = alloys[alloy]['comp']
    dens = alloys[alloy]['dens']

    # Update axis label unit format to mm
    fig = figure(width=850, height=450, y_axis_type="log",
                 x_axis_label="Thickness / Depth (mm)", y_axis_label="Conc (cm^-3)")
    fig.axis.major_label_text_font_size = "13pt"
    fig.axis.axis_label_text_font_size = "14pt"

    # Generate grid dynamic to the millimeter selection
    X_GRID_mm = np.linspace(0, thick, 500)
    X_GRID_cm = X_GRID_mm / 10.0  # Convert to cm for formula compatibility

    all_depth_ys = []

    for i, el in enumerate(ELEMENTS):
        c_wt = comp.get(el, 0)

        if el not in allowed or c_wt == 0:
            continue

        if override:
            c0 = custom_c0
        else:
            c0 = (dens * (c_wt/100) * 6.022e23) / atom_database[el]

        ds = [p[0] * np.exp(-p[1] / (R * T_k)) for p in alloy_imp_dict[el]]
        element_color = COLORS[i]

        for param_set_idx, d in enumerate(ds):
            method_name = f"Method {param_set_idx + 1}"

            if method_name not in selected_methods:
                continue

            if d <= 0:
                d_p_single = np.zeros_like(X_GRID_mm)
            else:
                d_p_single = c0 * (1 - erf(X_GRID_cm / (2 * np.sqrt(d * t_sec_now))))

            positive_values = d_p_single[d_p_single > 0]
            if positive_values.size > 0:
                all_depth_ys.extend(positive_values.tolist())

            legend_label = f"{el} {method_name}"
            line_dash = LINE_STYLES[param_set_idx % len(LINE_STYLES)]

            # Map out using X_GRID_mm for structural layout visualization
            fig.line(X_GRID_mm, d_p_single, color=element_color, line_width=2,
                     legend_label=legend_label, line_dash=line_dash, name=el)

    fig.legend.location = "top_right"
    fig.legend.click_policy = "hide"
    fig.legend.label_text_font_size = "10pt"
    fig.legend.background_fill_alpha = 0.8
    fig.legend.border_line_color = None

    # Update tooltip text units
    hover = HoverTool(tooltips=[("Element", "$name"), ("Depth (mm)", "$x{0.000}"), ("Conc (cm^-3)", "$y{0.00e+0}")])
    fig.add_tools(hover)

    fig.x_range.start = 0
    fig.x_range.end = thick

    if all_depth_ys:
        min_depth_y = np.min(all_depth_ys)
        max_depth_y = np.max(all_depth_ys)
        if min_depth_y <= 0: min_depth_y = 1e-15

        if min_depth_y >= max_depth_y:
            log_val = np.log10(min_depth_y)
            fig.y_range.start = max(1e-15, 10**(log_val - 1))
            fig.y_range.end = 10**(log_val + 1)
        else:
            log_min = np.log10(min_depth_y)
            log_max = np.log10(max_depth_y)
            span = log_max - log_min
            buffer = span * 0.1 if span >= 0.5 else 1.0

            fig.y_range.start = max(1e-15, 10**(log_min - buffer))
            fig.y_range.end = 10**(log_max + buffer)
    else:
        fig.y_range.start = 1e-10
        fig.y_range.end = 1e0

    return fig

interactive_plot = pn.bind(create_plot, alloy_w, group_w, temp_w, time_w, thick_w, override_w, custom_c0_w, method_select)

app = pn.Column(
    "## Diffusion Profile Analyzer",
    pn.Row(alloy_w, group_w),
    pn.Row(temp_w, time_w, thick_w),
    pn.Row(override_w, custom_c0_w, method_select),
    interactive_plot
).servable()

app
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='5b3190c6-45ef-4e7c-bc09-fbd56d1ca529'>
#   <div id="d2f334b1-45c3-4495-9864-3914bc716005" data-root-id="5b3190c6-45ef-4e7c-bc09-fbd56d1ca529" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# !pip install ipympl  # for interactive matplotlib in Colab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.0/519.0 kB 10.1 MB/s eta 0:00:00
# ...

# %%
 # if not already installed

import numpy as np
from scipy.special import erf
import matplotlib.pyplot as plt
from ipywidgets import interact, widgets

# ---------- Diffusion data ----------
table_data = {
    "Al": [(1.30e-5, 159.5)],
    "Sc": [(1.07e-5, 173.15), (1.22e-3, 218.70), (2.41e-4, 203.12)],
    "Cr": [(3.26e-4, 210.0), (2.58e-3, 225.93), (4.27e-4, 208.64)],
    "Ga": [(4.20e-5, 162.9), (5.21e-6, 166.27), (4.99e-6, 165.85)],
    "Y":  [(2.17e-5, 180.0), (2.66e-3, 226.22), (2.97e-4, 205.16)],
    "Zr": [(3.60e-6, 162.72), (3.90e-3, 229.91), (4.64e-4, 209.44)],
    "Mo": [(2.23e-6, 158.11), (3.63e-2, 251.35), (2.35e-3, 225.04)],
    "La": [(1.17e-5, 174.02), (2.99e-4, 205.22), (8.92e-5, 193.58)],
    "Hf": [(2.29e-6, 158.37), (1.58e-2, 243.35), (1.11e-3, 217.82)],
    "In": [(5.5e-5, 175.0), (5.25e-6, 166.34), (4.99e-6, 165.85)],
    "Yb": [(2.17e-5, 180.0), (6.63e-5, 190.73), (5.49e-5, 188.92)]
}

R = 8.31446e-3  # kJ/(mol·K)
ELEMENTS = list(table_data.keys())

# ---------- Plotting function ----------
def update_plot(elements, temp_C, time_days, max_depth_mm, surface_conc):
    temp_K = temp_C + 273.15
    t_sec = time_days * 86400

    # Convert max depth from mm to cm for calculation
    max_depth_cm = max_depth_mm / 10.0

    # Create depth array in cm (for calculation) and in mm (for plotting)
    x_cm = np.linspace(0, max_depth_cm, 500)
    x_mm = x_cm * 10

    fig, ax = plt.subplots(figsize=(10, 6))
    colors = plt.cm.tab20.colors

    for i, el in enumerate(elements):
        color = colors[i % len(colors)]
        for idx, (D0, Q) in enumerate(table_data[el]):
            D = D0 * np.exp(-Q / (R * temp_K))
            conc = surface_conc * (1 - erf(x_cm / (2 * np.sqrt(D * t_sec))))
            linestyle = '-' if idx == 0 else '--'
            label = f"{el} (method {idx+1})"
            ax.plot(x_mm, conc, color=color, linestyle=linestyle, linewidth=2, label=label)

    ax.set_xlabel("Depth (mm)", fontsize=12)
    ax.set_ylabel("Concentration (cm⁻³)", fontsize=12)
    ax.set_yscale('log')
    ax.set_title("Diffusion Profile (Outside → In)")
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    ax.grid(True, which='both', linestyle=':', alpha=0.5)
    ax.set_xlim(0, max_depth_mm)
    plt.tight_layout()
    plt.show()

# ---------- Interactive widgets (depth now in mm) ----------
widgets.interact(
    update_plot,
    elements=widgets.SelectMultiple(
        options=ELEMENTS,
        value=['Al', 'Zr'],
        description='Elements:',
        style={'description_width': 'initial'}
    ),
    temp_C=widgets.IntSlider(value=700, min=400, max=1200, step=10, description='Temp (°C):'),
    time_days=widgets.IntSlider(value=10, min=1, max=100, step=1, description='Time (days):'),
    max_depth_mm=widgets.FloatSlider(value=2.0, min=0.1, max=10.0, step=0.1, description='Max depth (mm):'),
    surface_conc=widgets.FloatLogSlider(value=1e21, base=10, min=19, max=23, step=0.1, description='Surface conc. (cm⁻³):')
)
# Out:
# interactive(children=(SelectMultiple(description='Elements:', index=(0, 5), options=('Al', 'Sc', 'Cr', 'Ga', '…
# <function __main__.update_plot(elements, temp_C, time_days, max_depth_mm, surface_conc)>
